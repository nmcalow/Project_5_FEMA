# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV
from sklearn.metrics import r2_score
# %matplotlib inline
#Imports

# %%
train = pd.read_csv('../datasets/train.csv')
test = pd.read_csv('../datasets/test.csv')

# %%
Exter_dict = {'Po': 0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex': 4}
train['Exter Qual'].replace(Exter_dict, inplace = True)
test['Exter Qual'].replace(Exter_dict, inplace = True)

# %%
Heating_dict = {"Po": 0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex': 4}
train['Heating QC'].replace(Heating_dict, inplace = True)
test['Heating QC'].replace(Heating_dict, inplace = True)

# %%
train['Garage Yr Blt'].replace(np.nan, 1980, inplace = True)
test['Garage Yr Blt'].replace(np.nan, 1980, inplace = True)

# %%
Lot_dict = {'IR3': 0, 'IR2': 1, 'IR1': 2, 'Reg': 3}
train['Lot Shape'].replace(Lot_dict, inplace = True)
test['Lot Shape'].replace(Lot_dict, inplace = True)

# %%
train['Overall Cond'].value_counts()
# Out:
# 5    1168
# 6     368
# 7     270
# 8     101
# 4      70
# 3      35
# 9      29
# 2       6
# 1       4
# Name: Overall Cond, dtype: int64

# %%
train['Kitchen Qual'].replace(Exter_dict, inplace = True)
test['Kitchen Qual'].replace(Exter_dict, inplace = True)

# %%
train['Exter Cond'].replace(Exter_dict, inplace = True)
test['Exter Cond'].replace(Exter_dict, inplace = True)

# %%
dummy_vars = ['House Style', 'Central Air' ]

# %%
features = ['Overall Qual',
            'Overall Cond',
            'Year Built', 
            'Year Remod/Add', 
            'Total Bsmt SF',
            'Mas Vnr Area',
            '1st Flr SF',
            '2nd Flr SF',
            'Gr Liv Area', 
            'Full Bath', 
            'TotRms AbvGrd', 
            'Fireplaces', 
            'Garage Yr Blt', 
            'Garage Cars', 
            'Garage Area',
            'Exter Qual',
            'Kitchen Qual',
            'Exter Cond',
            'Heating QC',
            'Lot Shape'
           ]

# %%
plt.figure(figsize = (6,30))
sns.heatmap(train.corr()[['SalePrice']], annot = True,  cmap = 'coolwarm')

# %%
train[features].isnull().sum()
# Out:
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Total Bsmt SF      1
# Mas Vnr Area      22
# 1st Flr SF         0
# 2nd Flr SF         0
# Gr Liv Area        0
# Full Bath          0
# TotRms AbvGrd      0
# Fireplaces         0
# Garage Yr Blt      0
# Garage Cars        1
# Garage Area        1
# Exter Qual         0
# Kitchen Qual       0
# Exter Cond         0
# Heating QC         0
# Lot Shape          0
# dtype: int64

# %%
test['Mas Vnr Area'].replace(np.nan, 0, inplace = True)
train['Mas Vnr Area'].replace(np.nan, 0, inplace = True)

test['Total Bsmt SF'].replace(np.nan, 0, inplace = True)
train['Total Bsmt SF'].replace(np.nan, 0, inplace = True)

test['Garage Cars'].replace(np.nan, 0, inplace = True)
train['Garage Cars'].replace(np.nan, 0, inplace = True)

test['Garage Area'].replace(np.nan, 0, inplace = True)
train['Garage Area'].replace(np.nan, 0, inplace = True)

# %%
train[features].isnull().sum()
# Out:
# Overall Qual      0
# Overall Cond      0
# Year Built        0
# Year Remod/Add    0
# Total Bsmt SF     0
# Mas Vnr Area      0
# 1st Flr SF        0
# 2nd Flr SF        0
# Gr Liv Area       0
# Full Bath         0
# TotRms AbvGrd     0
# Fireplaces        0
# Garage Yr Blt     0
# Garage Cars       0
# Garage Area       0
# Exter Qual        0
# Kitchen Qual      0
# Exter Cond        0
# Heating QC        0
# Lot Shape         0
# dtype: int64

# %%
test[features].isnull().sum()
# Out:
# Overall Qual      0
# Overall Cond      0
# Year Built        0
# Year Remod/Add    0
# Total Bsmt SF     0
# Mas Vnr Area      0
# 1st Flr SF        0
# 2nd Flr SF        0
# Gr Liv Area       0
# Full Bath         0
# TotRms AbvGrd     0
# Fireplaces        0
# Garage Yr Blt     0
# Garage Cars       0
# Garage Area       0
# Exter Qual        0
# Kitchen Qual      0
# Exter Cond        0
# Heating QC        0
# Lot Shape         0
# dtype: int64

# %%
test.shape
# Out:
# (879, 80)

# %%
train.shape
# Out:
# (2051, 81)

# %%
train.loc[1699,'Garage Yr Blt'] = 1980

# %%
train = pd.get_dummies(train, columns = dummy_vars)
test = pd.get_dummies(test, columns = dummy_vars)

# %%
train.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'Overall Qual', 'Overall Cond',
#        'Year Built', 'Year Remod/Add', 'Roof Style', 'Roof Matl',
#        'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area',
#        'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond',
#        'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2',
#        'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu',
# ...

# %%
model = LinearRegression()
X = train[features]
y = train['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

# %%
cross_val_score(model, X_train, y_train, cv = 5).mean()
# Out:
# 0.7805766094911745

# %%
poly = PolynomialFeatures(include_bias=False)

# %%
X_poly = poly.fit_transform(X_train)

# %%
cross_val_score(model, X_poly, y_train, cv = 5).mean()
# Out:
# 0.6616659242679636

# %%
poly_df = pd.DataFrame(X_poly, columns = poly.get_feature_names(features))

# %%
poly_df['SalePrice'] = y_train

# %%
#plt.figure(figsize = (6,30))
#NOT WORTH
#sns.heatmap(poly_df.corr()[['SalePrice']], annot = True, cmap = 'coolwarm')

# %%
dummy_features = ['House Style_1.5Fin', 
            'House Style_1.5Unf', 
            'House Style_2.5Fin', 
            'House Style_2.5Unf', 
            'House Style_2Story',
            'House Style_SFoyer', 
            'House Style_SLvl',
            'Central Air_N']
#features += dummy_features
#Realized it had an adverse effect on my model so I kept it off

# %%
model = LinearRegression()
X = train[features]
y = train['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

# %%
cross_val_score(model, X_train, y_train, cv = 5).mean()
# Out:
# 0.7805766094911745

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.score(X_train, y_train)
# Out:
# 0.8063146703682469

# %%
model.score(X_test, y_test)
# Out:
# 0.8626119826425596

# %%
# Instantiate Standard Scaler.
ss_scale = StandardScaler()

# Fit AND transform Standard Scaler to overfit data in one step.
Z_ss_train = pd.DataFrame(ss_scale.fit_transform(X_train))
Z_ss_test = pd.DataFrame(ss_scale.fit_transform(X_test))
# Out:
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
ridge_model = Ridge()
# Set up a list of ridge alphas to check.
r_alphas = np.logspace(0, 5, 100)
# Generates 100 values equally between 0 and 5,
# then converts them to alphas between 10^0 and 10^5.

# Cross-validate over our list of ridge alphas.
ridge_model = RidgeCV(alphas=r_alphas, scoring='r2', cv=5)

# Fit model using best ridge alpha!
ridge_model = ridge_model.fit(Z_ss_train, y_train)
#code taken from lesson

# %%
ridge_model.alpha_
# Out:
# 335.1602650938841

# %%
ridge_model.score(Z_ss_train, y_train)
# Out:
# 0.803876109739988

# %%
ridge_model.score(Z_ss_test, y_test)
# Out:
# 0.8585138401623343

# %%
# Set up a list of Lasso alphas to check.
l_alphas = np.logspace(-3, 5, 1000)

# Cross-validate over our list of Lasso alphas.
lasso_model = LassoCV(alphas=l_alphas, cv=5)

# Fit model using best ridge alpha!
lasso_model = lasso_model.fit(Z_ss_train, y_train)

# %%
lasso_model.alpha_
# Out:
# 843.1909292866251

# %%
lasso_model.score(Z_ss_train, y_train)
# Out:
# 0.8055965873143415

# %%
lasso_model.score(Z_ss_test, y_test)
# Out:
# 0.8632096199611038

# %%
# Set up a list of alphas to check.
enet_alphas = np.linspace(0, 1.0, 1000)

# Set up our l1 ratio. (What does this do?)
enet_ratio = 0.5

# Instantiate model.
enet_model = ElasticNetCV(alphas=enet_alphas, l1_ratio=enet_ratio, cv=5)

# Fit model using optimal alpha.
enet_model = enet_model.fit(Z_ss_train, y_train)
# Out:
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:474: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:474: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
# ...

# %%
enet_model.alpha_
# Out:
# 0.45245245245245247

# %%
enet_model.score(Z_ss_train, y_train)
# Out:
# 0.8037359379424972

# %%
enet_model.score(Z_ss_test, y_test)
# Out:
# 0.8582464642521281

# %%
def r2_adj(r2,X):
    return 1 - ((1-r2)*(len(X)-1))/(len(X)-len(X.columns)-1)

def print_metrics(model_pass, X_pass,y_pass ):
    residual = model_pass.predict(X_pass) - y_pass
    print(f"Mean squared error: {(residual**2).mean()}")
    r2 = model_pass.score(X_pass, y_pass)
    print(f"R Squared value: {r2}")
    print(f"Adjusted R Squared Value: {r2_adj(r2, X)}")
    print(f"Root mean squared error: {np.sqrt((residual**2).mean())}")
    print(f'Residual sum of squares: {(residual**2).sum()}')
    print(f"Residual mean: {residual.mean()}")

# %%
print_metrics(lasso_model, Z_ss_test, y_test)
# Out:
# Mean squared error: 839896316.3074521
# R Squared value: 0.8632096199611038
# Adjusted R Squared Value: 0.8618619314878142
# Root mean squared error: 28980.964723546593
# Residual sum of squares: 430866810265.7227
# Residual mean: -1630.0376910343823

# %%
print_metrics(lasso_model, Z_ss_train, y_train)
# Out:
# Mean squared error: 1229508315.6782134
# R Squared value: 0.8055965873143415
# Adjusted R Squared Value: 0.803681282755862
# Root mean squared error: 35064.3453621797
# Residual sum of squares: 1890983789513.0916
# Residual mean: 1.3056985055361675e-12

# %%
cross_val_score(lasso_model, Z_ss_train, y_train, cv= 5).mean()
# Out:
# 0.7831952268834467

# %%
X_test_real = test[features]

# %%
Z_ss_test_test = pd.DataFrame(ss_scale.fit_transform(X_test_real))
# Out:
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\NICK\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
y_pred = lasso_model.predict(Z_ss_test_test)

# %%
# LASSO seems to be my winner here

# %%
y_pred.shape
# Out:
# (879,)

# %%
test['SalePrice'] = y_pred

# %%
submission = test[['Id', 'SalePrice']]

# %%
submission.to_csv("Submission3.csv", index = False)
